# %% [markdown]
# # UNZIP

# %%
from google.colab import drive
drive.mount('M_drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at M_drive

# %%
import zipfile
import sys,os


a=os.getcwd();
b="M_drive/My Drive/SeminarAMS/"
save_dir="M_drive/My Drive/SeminarAMS/"

with zipfile.ZipFile(b+"x_testDOWN.zip", 'r') as zip_ref:
    zip_ref.extractall(save_dir)

# %%
import zipfile
import sys,os

with zipfile.ZipFile("super-resolution-master.zip", 'r') as zip_ref:
    zip_ref.extractall()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-23d3f43a0586> in <module>
#       2 import sys,os
#       3
# ----> 4 with zipfile.File("super-resolution-master.zip", 'r') as zip_ref:
#       5     zip_ref.extractall()
#
# AttributeError: module 'zipfile' has no attribute 'File'

# %% [markdown]
# # ZIP

# %%
import os
import zipfile

path="M_drive/My Drive/SeminarAMS/"
b="M_drive/My Drive/SeminarAMS/dataset_MRI_real/dataset_split/y_train/.npy"

zip_file = zipfile.ZipFile('y_train.zip', 'w')
zip_file.write(path+b, compress_type=zipfile.ZIP_DEFLATED)
zip_file.close()
